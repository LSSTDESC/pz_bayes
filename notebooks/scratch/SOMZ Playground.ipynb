# %% [markdown]
# ### Compare SOM algorithm with SOMz
#
# SOMz is a module that is part of MLZ (https://github.com/mgckind/MLZ). The core elements of the module have been copied to this notebook and made python-3 compatible in order to debug issues with our current SOM algorithm.
#
# More on the SOMz module here: http://matias-ck.com/mlz/somz.html

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import numpy
import time
import copy
import sys, os, random
import warnings

warnings.simplefilter("ignore", RuntimeWarning)
try:
    import somF
    SF90 = True
except:
    SF90 = False

# %%
import sys
sys.path.append('/Users/belaabolfathi/Documents/repos/pz_bayes/python')

import som

# %%
def get_index(ix, iy, nx, ny):
    return iy * nx + ix


def get_pair(ii, nx, ny):
    iy = int(numpy.floor(ii / nx))
    ix = ii % nx
    return ix, iy


def get_ns(ix, iy, nx, ny, index=False):
    """
    Get neighbors for rectangular grid given its
    coordinates and size of grid

    :param int ix: Coordinate in the x-axis
    :param int iy: Coordinate in the y-axis
    :param int nx: Number fo cells along the x-axis
    :param int ny: Number fo cells along the y-axis
    :param bool index: Return indexes in the map format
    :return: Array of indexes for direct neighbors
    """
    ns = []
    if ix - 1 >= 0: ns.append((ix - 1, iy))
    if iy - 1 >= 0: ns.append((ix, iy - 1))
    if ix + 1 < nx: ns.append((ix + 1, iy))
    if iy + 1 < ny: ns.append((ix, iy + 1))

    if ix - 1 >= 0 and iy - 1 >= 0: ns.append((ix - 1, iy - 1))
    if ix - 1 >= 0 and iy + 1 < ny: ns.append((ix - 1, iy + 1))
    if ix + 1 < nx and iy + 1 < ny: ns.append((ix + 1, iy + 1))
    if ix + 1 < nx and iy - 1 >= 0: ns.append((ix + 1, iy - 1))

    ns = numpy.array(ns)
    if not index:
        return ns
    if index:
        ins = []
        for i in range(len(ns)):
            ins.append(get_index(ns[i, 0], ns[i, 1], nx, ny))
        return numpy.array(ins)


def get_ns_hex(ix, iy, nx, ny, index=False):
    """
    Get neighbors for hexagonal grid given its coordinates
    and size of grid
    Same parameters as :func:`get_ns`
    """
    ns = []
    even = False
    if iy % 2 == 0: even = True
    if ix - 1 >= 0: ns.append((ix - 1, iy))
    if ix + 1 < nx: ns.append((ix + 1, iy))
    if iy - 1 >= 0: ns.append((ix, iy - 1))
    if iy + 1 < ny: ns.append((ix, iy + 1))
    if even and ix - 1 >= 0 and iy - 1 >= 0: ns.append((ix - 1, iy - 1))
    if even and ix - 1 >= 0 and iy + 1 < ny: ns.append((ix - 1, iy + 1))
    if not even and ix + 1 < nx and iy - 1 >= 0: ns.append((ix + 1, iy - 1))
    if not even and ix + 1 < nx and iy + 1 < ny: ns.append((ix + 1, iy + 1))
    ns = numpy.array(ns)
    if not index:
        return ns
    if index:
        ins = []
        for i in range(len(ns)):
            ins.append(get_index(ns[i, 0], ns[i, 1], nx, ny))
        return numpy.array(ins)


def geometry(top, Ntop, periodic='no'):
    """
    Pre-compute distances between cells in a given topology
    and store it on a distLib array

    :param str top: Topology ('grid','hex','sphere')
    :param int Ntop: Size of map,  for grid Size=Ntop*Ntop,
        for hex Size=Ntop*(Ntop+1[2]) if Ntop is even[odd] and for sphere
        Size=12*Ntop*Ntop and top must be power of 2
    :param str periodic: Use periodic boundary conditions ('yes'/'no'), valid for 'hex' and 'grid' only
    :return: 2D array with distances pre computed between cells and total number of units
    :rtype: 2D float array, int
    """
    if top == 'sphere':
        try:
            import healpy as hpx
        except:
            print('Error: healpy module not found, use grid or hex topologies')
            sys.exit(0)
    if top == 'sphere':
        nside = Ntop
        npix = 12 * nside ** 2
        distLib = numpy.zeros((npix, npix))
        for i in range(npix):
            ai = hpx.pix2ang(nside, i)
            for j in range(i + 1, npix):
                aj = hpx.pix2ang(nside, j)
                distLib[i, j] = hpx.rotator.angdist(ai, aj)
                distLib[j, i] = distLib[i, j]
        distLib[numpy.where(numpy.isnan(distLib))] = numpy.pi
    if top == 'grid':
        nx = Ntop
        ny = Ntop
        npix = nx * ny
        mapxy = numpy.mgrid[0:1:complex(0, nx), 0:1:complex(0, ny)]
        mapxy = numpy.reshape(mapxy, (2, npix))
        bX = mapxy[1]
        bY = mapxy[0]
        dx = 1. / (nx - 1)
        dy = 1. / (ny - 1)
        distLib = numpy.zeros((npix, npix))
        if periodic == 'no':
            for i in range(npix):
                for j in range(i + 1, npix):
                    distLib[i, j] = numpy.sqrt((bX[i] - bX[j]) ** 2 + (bY[i] - bY[j]) ** 2)
                    distLib[j, i] = distLib[i, j]
        if periodic == 'yes':
            for i in range(npix):
                for j in range(i + 1, npix):
                    s0 = numpy.sqrt((bX[i] - bX[j]) ** 2 + (bY[i] - bY[j]) ** 2)
                    s1 = numpy.sqrt((bX[i] - (bX[j] + 1. + dx)) ** 2 + (bY[i] - bY[j]) ** 2)
                    s2 = numpy.sqrt((bX[i] - (bX[j] + 1. + dx)) ** 2 + (bY[i] - (bY[j] + 1. + dy)) ** 2)
                    s3 = numpy.sqrt((bX[i] - (bX[j] + 0.)) ** 2 + (bY[i] - (bY[j] + 1. + dy)) ** 2)
                    s4 = numpy.sqrt((bX[i] - (bX[j] - 1. - dx)) ** 2 + (bY[i] - (bY[j] + 1. + dy)) ** 2)
                    s5 = numpy.sqrt((bX[i] - (bX[j] - 1. - dx)) ** 2 + (bY[i] - (bY[j] + 0.)) ** 2)
                    s6 = numpy.sqrt((bX[i] - (bX[j] - 1. - dx)) ** 2 + (bY[i] - (bY[j] - 1. - dy)) ** 2)
                    s7 = numpy.sqrt((bX[i] - (bX[j] + 0.)) ** 2 + (bY[i] - (bY[j] - 1. - dy)) ** 2)
                    s8 = numpy.sqrt((bX[i] - (bX[j] + 1. + dx)) ** 2 + (bY[i] - (bY[j] - 1. - dy)) ** 2)
                    distLib[i, j] = numpy.min((s0, s1, s2, s3, s4, s5, s6, s7, s8))
                    distLib[j, i] = distLib[i, j]
    if top == 'hex':
        nx = Ntop
        ny = Ntop
        xL = numpy.arange(0, nx, 1.)
        dy = 0.8660254
        yL = numpy.arange(0, ny, dy)
        ny = len(yL)
        nx = len(xL)
        npix = nx * ny
        bX = numpy.zeros(nx * ny)
        bY = numpy.zeros(nx * ny)
        kk = 0
        last = ny * dy
        for jj in range(ny):
            for ii in range(nx):
                if jj % 2 == 0: off = 0.
                if jj % 2 == 1: off = 0.5
                bX[kk] = xL[ii] + off
                bY[kk] = yL[jj]
                kk += 1
        distLib = numpy.zeros((npix, npix))
        if periodic == 'no':
            for i in range(npix):
                for j in range(i + 1, npix):
                    distLib[i, j] = numpy.sqrt((bX[i] - bX[j]) ** 2 + (bY[i] - bY[j]) ** 2)
                    distLib[j, i] = distLib[i, j]
        if periodic == 'yes':
            for i in range(npix):
                for j in range(i + 1, npix):
                    s0 = numpy.sqrt((bX[i] - bX[j]) ** 2 + (bY[i] - bY[j]) ** 2)
                    s1 = numpy.sqrt((bX[i] - (bX[j] + nx)) ** 2 + (bY[i] - bY[j]) ** 2)
                    s2 = numpy.sqrt((bX[i] - (bX[j] + nx)) ** 2 + (bY[i] - (bY[j] + last)) ** 2)
                    s3 = numpy.sqrt((bX[i] - (bX[j] + 0)) ** 2 + (bY[i] - (bY[j] + last)) ** 2)
                    s4 = numpy.sqrt((bX[i] - (bX[j] - nx)) ** 2 + (bY[i] - (bY[j] + last)) ** 2)
                    s5 = numpy.sqrt((bX[i] - (bX[j] - nx)) ** 2 + (bY[i] - (bY[j] + 0)) ** 2)
                    s6 = numpy.sqrt((bX[i] - (bX[j] - nx)) ** 2 + (bY[i] - (bY[j] - last)) ** 2)
                    s7 = numpy.sqrt((bX[i] - (bX[j] + 0)) ** 2 + (bY[i] - (bY[j] - last)) ** 2)
                    s8 = numpy.sqrt((bX[i] - (bX[j] + nx)) ** 2 + (bY[i] - (bY[j] - last)) ** 2)
                    distLib[i, j] = numpy.min((s0, s1, s2, s3, s4, s5, s6, s7, s8))
                    distLib[j, i] = distLib[i, j]
    return distLib, npix


def is_power_2(value):
    """
    Check if passed value is a power of 2
    """
    return value!=0 and ((value & (value- 1)) == 0)


def get_alpha(t, alphas, alphae, NT):
    """
    Get value of alpha at a given time
    """
    return alphas * numpy.power(alphae / alphas, float(t) / float(NT))


def get_sigma(t, sigma0, sigmaf, NT):
    """
    Get value of sigma at a given time
    """
    return sigma0 * numpy.power(sigmaf / sigma0, float(t) / float(NT))


def h(bmu, mapD, sigma):
    """
    Neighborhood function which quantifies how much cells around the best matching one are modified

    :param int bmu: best matching unit
    :param float mapD: array of distances computed with :func:`geometry`
    """
    return numpy.exp(-(mapD[bmu] ** 2) / sigma ** 2)

# %%
class SelfMap():
    """
    Create a som class instance

    :param float X: Attributes array (all columns used)
    :param float Y: Attribute to be predicted (not really needed, can be zeros)
    :param str topology: Which 2D topology, 'grid', 'hex' or 'sphere'
    :param str som_type: Which updating scheme to use 'online' or 'batch'
    :param int Ntop: Size of map,  for grid Size=Ntop*Ntop,
        for hex Size=Ntop*(Ntop+1[2]) if Ntop is even[odd] and for sphere
        Size=12*Ntop*Ntop and top must be power of 2
    :param  int iterations: Number of iteration the entire sample is processed
    :param str periodic: Use periodic boundary conditions ('yes'/'no'), valid for 'hex' and 'grid' only
    :param dict dict_dim: dictionary with attributes names
    :param float astar: Initial value of alpha
    :param float aend: End value of alpha
    :param str importance: Path to the file with importance ranking for attributes, default is none
    """

    def __init__(self, X, Y, topology='grid', som_type='online', Ntop=28, iterations=30, periodic='no', dict_dim='',
                 astart=0.8, aend=0.5, importance=None):
        self.np, self.nDim = numpy.shape(X)
        self.dict_dim = dict_dim
        self.X = X
        self.SF90 = SF90
        self.Y = Y
        self.aps = astart
        self.ape = aend
        self.top = topology
        if topology=='sphere' and not is_power_2(Ntop):
            print('Error, Ntop must be power of 2')
            sys.exit(0)
        self.stype = som_type
        self.Ntop = Ntop
        self.nIter = iterations
        self.per = periodic
        self.distLib, self.npix = geometry(self.top, self.Ntop, periodic=self.per)
        if importance == None: importance = numpy.ones(self.nDim)
        self.importance = importance / numpy.sum(importance)
        # Added
        #self.store_weights = np.empty((self.nIter, self.np, self.nDim, self.npix))
        self.loss = np.empty(self.nIter)

    def som_best_cell(self, inputs, return_vals=1):
        """
        Return the closest cell to the input object
        It can return more than one value if needed
        """
        activations = numpy.sum(numpy.transpose([self.importance]) * (
            numpy.transpose(numpy.tile(inputs, (self.npix, 1))) - self.weights) ** 2, axis=0)
        if return_vals == 1:
            best = numpy.argmin(activations)
            return best, activations
        else:
            best_few = numpy.argsort(activations)
            return best_few[0:return_vals], activations

    def create_map(self, evol='no', inputs_weights='', seed=123):
        """
        This is same as above but uses python routines instead
        """
        
        # Added
        rng = np.random.RandomState(seed=seed)
        
        if inputs_weights == '':
            # Added
            self.weights = rng.random_sample(size=(self.nDim, self.npix)) + self.X[0][0]
            #self.weights = (numpy.random.rand(self.nDim, self.npix)) + self.X[0][0]
        else:
            self.weights = inputs_weights
        self.NT = self.nIter * self.np
        if self.stype == 'online':
            tt = 0
            sigma0 = self.distLib.max()
            sigma_single = numpy.min(self.distLib[numpy.where(self.distLib > 0.)])
            # Added
            #self.store_weights = np.empty((self.nIter, self.np, self.nDim, self.npix))
            for it in range(self.nIter):
                #get alpha, sigma
                alpha = get_alpha(tt, self.aps, self.ape, self.NT)
                sigma = get_sigma(tt, sigma0, sigma_single, self.NT)
                #index_random = random.sample(range(self.np), self.np)
                # Added
                index_random = rng.choice(np.arange(self.np), size=self.np, replace=False)
                loss = 0.
                for i in range(self.np):
                    tt += 1
                    inputs = self.X[index_random[i]]
                    # Added
                    #inputs = self.X[i]
                    best, activation = self.som_best_cell(inputs)
                    loss += np.sum((inputs - numpy.transpose(M.weights))[best])
                    self.weights += alpha * h(best, self.distLib, sigma) * numpy.transpose(
                        (inputs - numpy.transpose(self.weights)))
                    # Added
                    #self.store_weights[it,i] = self.weights
                self.loss[it] = loss
                if evol == 'yes':
                    self.evaluate_map()
                    self.save_map(itn=it)
        if self.stype == 'batch':
            tt = 0
            sigma0 = self.distLib.max()
            sigma_single = numpy.min(self.distLib[numpy.where(self.distLib > 0.)])
            for it in range(self.nIter):
                #get alpha, sigma
                sigma = get_sigma(tt, sigma0, sigma_single, self.NT)
                accum_w = numpy.zeros((self.nDim, self.npix))
                accum_n = numpy.zeros(self.npix)
                for i in range(self.np):
                    tt += 1
                    inputs = self.X[i]
                    best, activation = self.som_best_cell(inputs)
                    for kk in range(self.nDim):
                        accum_w[kk, :] += h(best, self.distLib, sigma) * inputs[kk]
                    accum_n += h(best, self.distLib, sigma)
                for kk in range(self.nDim):
                    self.weights[kk] = accum_w[kk] / accum_n

                if evol == 'yes':
                    self.evaluate_map()
                    self.save_map(itn=it)

    def evaluate_map(self, inputX='', inputY=''):
        """
        This functions evaluates the map created using the input Y or a new Y (array of labeled attributes)
        It uses the X array passed or new data X as well, the map doesn't change

        :param float inputX: Use this if another set of values for X is wanted using
            the weigths already computed
        :param float inputY: One  dimensional array of the values to be assigned to each cell in the map
            based on the in-memory X passed
        """
        self.yvals = {}
        self.ivals = {}
        if inputX == '':
            inX = self.X
        else:
            inX = inputX
        if inputY == '':
            inY = self.Y
        else:
            inY = inputY
        for i in range(len(inX)):
            inputs = inX[i]
            best, activation = self.som_best_cell(inputs)
            if not best in self.yvals: self.yvals[best] = []
            self.yvals[best].append(inY[i])
            if not best in self.ivals: self.ivals[best] = []
            self.ivals[best].append(i)

    def get_vals(self, line):
        """
        Get the predictions  given a line search, where the line
        is a vector of attributes per individual object fot the
        10 closest cells.

        :param float line: input data to look in the tree
        :return: array with the cell content
        """
        best, act = self.som_best_cell(line, return_vals=10)
        for ib in range(10):
            if best[ib] in self.yvals: return self.yvals[best[ib]]
        return numpy.array([-1.])

    def get_best(self, line):
        """
        Get the predictions  given a line search, where the line
        is a vector of attributes per individual object for THE best cell

        :param float line: input data to look in the tree
        :return: array with the cell content
        """
        best, act = self.som_best_cell(line, return_vals=10)
        return best[0]

    def save_map(self, itn=-1, fileout='SOM', path=''):
        """
        Saves the map

        :param int itn: Number of map to be included on path, use -1 to ignore this number
        :param str fileout: Name of output file
        :param str path: path for the output file
        """
        if path == '':
            path = os.getcwd() + '/'
        if not os.path.exists(path): os.system('mkdir -p ' + path)
        if itn >= 0:
            ff = '_%04d' % itn
            fileout += ff
        numpy.save(path + fileout, self)

    def save_map_dict(self, path='', fileout='SOM', itn=-1):
        """
        Saves the map in dictionary format

        :param int itn: Number of map to be included on path, use -1 to ignore this number
        :param str fileout: Name of output file
        :param str path: path for the output file
        """
        SOM = {}
        SOM['W'] = self.weights
        SOM['yvals'] = self.yvals
        SOM['ivals'] = self.ivals
        SOM['topology'] = self.top
        SOM['Ntop'] = self.Ntop
        SOM['npix'] = self.npix
        if path == '':
            path = os.getcwd() + '/'
        if not os.path.exists(path): os.system('mkdir -p ' + path)
        if itn > 0:
            ff = '_%04d' % itn
            fileout += ff
        numpy.save(path + fileout, SOM)

    def plot_map(self, min_m=-100, max_m=-100, colbar='yes'):
        """
        Plots the map after evaluating, the cells are colored with the mean value inside each
        one of them

        :param float min_m: Lower limit for coloring the cells, -100 uses min value
        :param float max_m: Upper limit for coloring the cells, -100 uses max value
        :param str colbar: Include a colorbar ('yes','no')
        """

        import matplotlib.pyplot as plt
        #from matplotlib import mpl
        # see https://stackoverflow.com/questions/44499971/importerror-cannot-import-name-mpl-from-matplotlib-import-mpl
        import matplotlib as mpl
        import matplotlib.cm as cm
        from matplotlib import collections, transforms
        from matplotlib.colors import colorConverter

        if self.top == 'sphere': import healpy as H

        if self.top == 'grid':
            M = numpy.zeros(self.npix) - 20.
            for i in range(self.npix):
                if i in self.yvals:
                    M[i] = numpy.mean(self.yvals[i])
            M2 = numpy.reshape(M, (self.Ntop, self.Ntop))
            plt.figure(figsize=(8, 8), dpi=100)
            if min_m == -100: min_m = M2[numpy.where(M2 > -10)].min()
            if max_m == -100: max_m = M2.max()
            SM2 = plt.imshow(M2, origin='center', interpolation='nearest', cmap=cm.jet, vmin=min_m, vmax=max_m)
            SM2.cmap.set_under("grey")
            if colbar == 'yes': plt.colorbar()
            plt.axis('off')
        if self.top == 'hex':
            nx = self.Ntop
            ny = self.Ntop
            xL = numpy.arange(0, nx, 1.)
            dy = 0.8660254
            yL = numpy.arange(0, ny, dy)
            ny = len(yL)
            nx = len(xL)
            npix = nx * ny
            bX = numpy.zeros(nx * ny)
            bY = numpy.zeros(nx * ny)
            kk = 0
            for jj in range(ny):
                for ii in range(nx):
                    if jj % 2 == 0: off = 0.
                    if jj % 2 == 1: off = 0.5
                    bX[kk] = xL[ii] + off
                    bY[kk] = yL[jj]
                    kk += 1
            xyo = list(zip(bX, bY))
            sizes_2 = numpy.zeros(nx * ny) + ((8. * 0.78 / (self.Ntop + 0.5)) / 2. * 72.) ** 2 * 4. * numpy.pi / 3.
            M = numpy.zeros(npix) - 20.
            fcolors = [plt.cm.Spectral_r(x) for x in numpy.random.rand(nx * ny)]
            for i in range(npix):
                if i in self.yvals:
                    M[i] = numpy.mean(self.yvals[i])
            if max_m == -100: max_m = M.max()
            if min_m == -100: min_m = M[numpy.where(M > -10)].min()
            M = M - min_m
            M = M / (max_m - min_m)
            for i in range(npix):
                if M[i] <= 0:
                    fcolors[i] = plt.cm.Greys(.5)
                else:
                    fcolors[i] = plt.cm.jet(M[i])
            figy = ((8. * 0.78 / (self.Ntop + 0.5) / 2.) * (3. * ny + 1) / numpy.sqrt(3)) / 0.78
            fig3 = plt.figure(figsize=(8, figy), dpi=100)
            #fig3.subplots_adjust(left=0,right=1.,top=1.,bottom=0.)
            a = fig3.add_subplot(1, 1, 1)
            col = collections.RegularPolyCollection(6, sizes=sizes_2, offsets=xyo, transOffset=a.transData)
            col.set_color(fcolors)
            a.add_collection(col, autolim=True)
            a.set_xlim(-0.5, nx)
            a.set_ylim(-1, nx + 0.5)
            plt.axis('off')
            if colbar == 'yes':
                figbar = plt.figure(figsize=(8, 1.), dpi=100)
                ax1 = figbar.add_axes([0.05, 0.8, 0.9, 0.15])
                cmap = cm.jet
                norm = mpl.colors.Normalize(vmin=min_m, vmax=max_m)
                cb1 = mpl.colorbar.ColorbarBase(ax1, cmap=cmap, norm=norm, orientation='horizontal')
                cb1.set_label('')
        if self.top == 'sphere':
            M = numpy.zeros(self.npix) + H.UNSEEN
            for i in range(self.npix):
                if i in self.yvals:
                    M[i] = numpy.mean(self.yvals[i])
            plt.figure(10, figsize=(8, 8), dpi=100)
            if min_m == -100: min_m = M[numpy.where(M > -10)].min()
            if max_m == -100: max_m = M.max()
            if colbar == 'yes': H.mollview(M, fig=10, title="", min=min_m, max=max_m, cbar=True)
            if colbar == 'no': H.mollview(M, fig=10, title="", min=min_m, max=max_m, cbar=False)
        plt.show()

# %% [markdown]
# ### Test on SDSS data

# %%
path = '/Users/belaabolfathi/Documents/repos/MLZ/mlz/test/'
X = loadtxt(path + 'SDSS_MGS.train', usecols=(1, 2, 3, 4, 5, 6, 7), unpack=True).T
Y = loadtxt(path + 'SDSS_MGS.train', unpack=True, usecols=(0,))

# %%
nside = 15
niter = 100

# %% [markdown]
# #### SOMz (SDSS)

# %%
start = time.time()
# Calls the SOMZ mode
M = SelfMap(X,Y,Ntop=nside,iterations=niter,periodic='yes')
# Creates a map
M.create_map()
# Evaluates it with the Y entered, or another desired column
M.evaluate_map()
# Plots the map
M.plot_map()
print(time.time() - start)
# Out:
# 44.188414096832275

# %%
# Could this be because SOMz does better at low z?
np.min(Y), np.max(Y)
# Out:
# (0.003017, 0.27634)

# %% [markdown]
# Plot the number of galaxies per cell when the training data is mapped back to the SOM:

# %%
# Plot counts per cell
counts = np.zeros(nside ** 2, dtype=int)
for i in range(nside **2): 
    try:
        counts[i] = len(M.yvals[i])
    except KeyError:
        pass

# %%
plt.figure(figsize=(10,7))
plt.imshow(counts.reshape(15,15), origin='lower')
plt.title('Number per SOM cell')
plt.colorbar();

# %%
pred = [np.mean(M.get_vals(X[i])) for i in range(len(X))]
plt.figure(figsize=(8,6))
plt.scatter(Y, pred, s=1)
plt.plot([0,0.3], [0,0.3], '--m')
plt.xlabel('True z')
plt.ylabel('Predicted z')
plt.xlim(0.,0.3)
plt.ylim(0.,0.3);

# %% [markdown]
# Note: running this will re-assign `M.yvals` by calling `evaluate_map` on the first feature

# %%
# Get prediction values for a test data (just an example on how to do it)
# using a train object
values = M.get_vals(X[10])
print('mean value from prediction (hex)', mean(values))
print('real value', Y[10])
# Note we use a low-resoution map and only one map for example purposes
# Evaluate another column, for example the 'g' magnitude
M.evaluate_map(inputY=X[:,1])
M.plot_map()
# Out:
# mean value from prediction (hex) 0.10998771428571427
# real value 0.120684
# /Users/belaabolfathi/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:130: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison

# %% [markdown]
# #### pz_bayes (SDSS)

# %%
import cProfile

# %%
som_pz = som.SelfOrganizingMap(som.Grid(-nside,-nside))
cProfile.run('som_pz.fit(X, maxiter=niter)')
som_pz.map_to_som(X,Y)
# Out:
#          9501052 function calls in 30.581 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000   30.581   30.581 <string>:1(<module>)
#       200    0.000    0.000    0.000    0.000 _internal.py:247(__init__)
#       200    0.000    0.000    0.000    0.000 _internal.py:272(get_data)
#         1    0.000    0.000    0.001    0.001 _methods.py:138(_std)
#         1    0.000    0.000    0.000    0.000 _methods.py:48(_count_reduce_items)
#         1    0.000    0.000    0.001    0.001 _methods.py:91(_var)
#    500000    0.361    0.000    1.486    0.000 fromnumeric.py:1040(argmin)
#   1000000    1.500    0.000    7.951    0.000 fromnumeric.py:1821(sum)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:2227(amax)
#       100    0.000    0.000    0.002    0.000 fromnumeric.py:2478(prod)
#         1    0.000    0.000    0.001    0.001 fromnumeric.py:2923(std)
#    500000    0.286    0.000    1.125    0.000 fromnumeric.py:49(_wrapfunc)
#   1000101    1.452    0.000    6.163    0.000 fromnumeric.py:64(_wrapreduction)
#         2    0.000    0.000    0.000    0.000 numeric.py:504(asanyarray)
#         4    0.000    0.000    0.000    0.000 som.py:11(size)
#    500000    4.424    0.000   10.757    0.000 som.py:141(find_bmu)
#         1   16.131   16.131   30.581   30.581 som.py:157(fit)
#    500001    0.153    0.000    0.158    0.000 som.py:17(separations)
#         5    0.000    0.000    0.000    0.000 som.py:66(shape)
#         1    0.005    0.005    0.005    0.005 som.py:78(_calculate_separations)
#         2    0.000    0.000    0.000    0.000 som.py:92(<listcomp>)
#         1    0.000    0.000   30.581   30.581 {built-in method builtins.exec}
#    500100    0.098    0.000    0.098    0.000 {built-in method builtins.getattr}
#   1000004    0.290    0.000    0.290    0.000 {built-in method builtins.isinstance}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#   1000001    0.107    0.000    0.107    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#         2    0.000    0.000    0.000    0.000 {built-in method numpy.core.multiarray.arange}
#         2    0.000    0.000    0.000    0.000 {built-in method numpy.core.multiarray.array}
#         3    0.000    0.000    0.000    0.000 {built-in method numpy.core.multiarray.empty}
#         1    0.000    0.000    0.000    0.000 {built-in method numpy.core.multiarray.zeros}
#    500000    0.741    0.000    0.741    0.000 {method 'argmin' of 'numpy.ndarray' objects}
#       100    0.014    0.000    0.016    0.000 {method 'choice' of 'mtrand.RandomState' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#   1000101    0.118    0.000    0.118    0.000 {method 'items' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'normal' of 'mtrand.RandomState' objects}
#   1000103    4.592    0.000    4.592    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#    500006    0.307    0.000    0.307    0.000 {method 'reshape' of 'numpy.ndarray' objects}

# %%
#np.allclose(som_pz._weights, M.weights, rtol=10)

# %%
plt.imshow(som_pz._weights[2:5].T.reshape(nside, nside, 3));

# %%
plt.imshow(M.weights[2:5].T.reshape(nside, nside, 3));

# %%
plt.plot(som_pz._loss, '.');

# %%
som_pz.plot_counts_per_cell(X)

# %%
# Mean redshift per cell
som_pz.plot_statistic()

# %%
# Mean value of feature 1 per cell
som_pz.plot_statistic(column=1)

# %%
# Redshift prediction for input X[10]
best = som_pz.find_bmu(X[10])
print('Mean value prediction is: {:.3}'.format(np.mean(som_pz._target_dist[best])))
# True redshift
print('Real value is: {:.3}'.format(Y[10]))
# Out:
# Mean value prediction is: 0.109
# Real value is: 0.121

# %%
# Distribution of feature 1 in best-matching cell
plt.hist(som_pz._feature_dist[best][:,1]);

# %%
som_pz.plot_sed_in_cell(42)

# %%
pred = [np.mean(som_pz._target_dist[best]) for best in som_pz.find_bmu(X)]
plt.figure(figsize=(8,6))
plt.scatter(Y, pred, s=1)
plt.plot([0,0.3], [0,0.3], '--m')
plt.xlabel('True z')
plt.ylabel('Predicted z')
plt.xlim(0.,0.3)
plt.ylim(0.,0.3);

# %% [markdown]
# Compare SOMz predicted with pz_bayes predicted:

# %%
somz_pred = [np.mean(M.get_vals(X[i])) for i in range(len(X))]
pz_pred = [np.mean(som_pz._target_dist[best]) for best in som_pz.find_bmu(X)]
plt.figure(figsize=(8,6))
plt.scatter(pz_pred, somz_pred, s=1)
plt.plot([0,0.3], [0,0.3], '--m')
plt.xlabel('pz predicted')
plt.ylabel('somz predicted')
plt.xlim(0.,0.3)
plt.ylim(0.,0.3);

# %% [markdown]
# ### Try on cosmoDC2 data
#
# #### SOMz

# %%
from astropy.table import Table

# %%
dc2_griz = Table.read('cosmodc2_colors/dc2_griz_colors.fits', format='fits')
# Convert to numpy array
colnames = dc2_griz.colnames
N, D = len(dc2_griz), len(colnames)
dat_arr = np.empty((N,D))

for i, name in enumerate(colnames):
    dat_arr[:,i] = dc2_griz[name]

# %%
dc2_table = Table.read('cosmodc2_colors/dc2_processed_table.fits', format='fits')
# Convert to numpy array
dc2_redshifts = np.array(dc2_table['redshift'])

# %%
X = dat_arr[::50]
Y = dc2_redshifts[::50]

# %%
plt.hist(dc2_redshifts[:3000], bins=50);

# %%
plt.hist(dc2_redshifts[::50], bins=1000);

# %%
nside = 20
niter = 10

# %%
#Calls the SOMZ mode
M = SelfMap(X,Y,Ntop=nside,iterations=niter,periodic='yes')
#creates a map
M.create_map()
#evaluates it with the Y entered, or another desired column
M.evaluate_map()
#plots the map
M.plot_map()

# %%
plt.plot(M.loss, '.');

# %%
np.min(Y), np.max(Y)
# Out:
# (0.014928413481736458, 3.0305308235436694)

# %%
# Plot counts per cell
counts = np.zeros(nside ** 2, dtype=int)
for i in range(nside **2): 
    try:
        counts[i] = len(M.yvals[i])
    except KeyError:
        pass

# %%
plt.figure(figsize=(10,7))
plt.imshow(counts.reshape(15,15), origin='lower')
plt.title('Number per SOM cell')
plt.colorbar();

# %%
pred = [np.mean(M.get_vals(X[i])) for i in range(len(X))]
plt.figure(figsize=(8,6))
plt.scatter(Y, pred, s=1)
plt.plot([0,3], [0,3], '--m')
plt.title('SOMz')
plt.xlabel('True z')
plt.ylabel('Predicted z')
plt.xlim(0.,3)
plt.ylim(0.,3);

# %%
M.evaluate_map(inputX=X_test, inputY=Y_test)
# Out:
# /Users/belaabolfathi/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:132: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# /Users/belaabolfathi/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:136: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison

# %%
# Plot counts per cell
counts = np.zeros(nside ** 2, dtype=int)
for i in range(nside **2): 
    try:
        counts[i] = len(M.yvals[i])
    except KeyError:
        pass

# %%
plt.figure(figsize=(10,7))
plt.imshow(counts.reshape(15,15), origin='lower')
plt.title('Number per SOM cell')
plt.colorbar();

# %% [markdown]
# pz_bayes learning rate

# %%
q = 100
plt.plot(0.8 ** (np.arange(q) / q), '.')
plt.plot(0.5 ** (np.arange(q) / q), '.')
plt.plot(0.1 ** (np.arange(q) / q), '.')
plt.plot(0.01 ** (np.arange(q) / q), '.');

# %% [markdown]
# #### pz_bayes

# %%
som_pz = som.SelfOrganizingMap(som.Grid(-nside,-nside))
som_pz.fit(dat_arr[::50], maxiter=niter, eta=0.8)
som_pz.map_to_som(dat_arr[::50],dc2_redshifts[::50])

# %%
## using mean separation
## eta = 0.8
som_pz.plot_counts_per_cell(dat_arr[::50])

# %% [markdown]
# ##### These parameters seem to work the best:

# %%
som_pz = som.SelfOrganizingMap(som.Grid(-nside,-nside))
som_pz.fit(dat_arr[::50], maxiter=niter, eta=0.5)
som_pz.map_to_som(dat_arr[::50],dc2_redshifts[::50])

# %%
## using mean separation
## eta = 0.5
som_pz.plot_counts_per_cell(dat_arr[::50])

# %%
som_pz = som.SelfOrganizingMap(som.Grid(-nside,-nside))
som_pz.fit(X, maxiter=niter, eta=0.5)
som_pz.map_to_som(X,Y)

# %%
## using mean separation
## eta = 0.5
som_pz.plot_counts_per_cell(X)

# %%
dat_arr.shape, len(X), len(dat_arr[::50])
# Out:
# ((1613192, 3), 33000, 32264)

# %%
fig, axs = plt.subplots(1,3, figsize=(15,4))
axs = axs.ravel()
for i in range(3):
    axs[i].plot(X[:32264,i], '.')
    axs[i].plot(dat_arr[::50,i], '.', alpha=0.1)
plt.show()

# %% [markdown]
# Try randomizing data and then making the same plots:

# %%
rng = np.random.RandomState(123)
mix = rng.choice(np.arange(len(dat_arr[::50])), size=len(dat_arr[::50]), replace=False)

# %%
#plt.plot(dat_arr[::50][:,0], '.')
#plt.plot(dat_arr[::50,0], '.', alpha=0.1)
plt.plot(X[:32264][mix][:,0], '.')
plt.plot(X[:32264,0], '.');

# %%
nside = 15
niter = 5

# %%
two_pc = len(dat_arr[::50])

# %% [markdown]
# #### First 32264 galaxies in cosmodc2 table

# %%
som_pz = som.SelfOrganizingMap(som.Grid(-nside,-nside))
som_pz.fit(dat_arr[:two_pc], maxiter=niter, eta=0.5)
som_pz.map_to_som(dat_arr[:two_pc], dc2_redshifts[:two_pc])

# %%
np.min(dc2_redshifts[:two_pc]), np.max(dc2_redshifts[:two_pc])
# Out:
# (0.0008889839271091216, 0.6184088227752296)

# %% [markdown]
# Randomizing each epoch:

# %%
som_pz.plot_counts_per_cell(dat_arr[:two_pc])

# %% [markdown]
# Shuffling once at the top did better:

# %%
som_pz.plot_counts_per_cell(dat_arr[:two_pc])

# %%
#Calls the SOMZ mode
M = SelfMap(dat_arr[:two_pc],dc2_redshifts[:two_pc],Ntop=nside,iterations=niter,periodic='yes')
#creates a map
M.create_map()
#evaluates it with the Y entered, or another desired column
M.evaluate_map()

# Plot counts per cell
counts = np.zeros(nside ** 2, dtype=int)
for i in range(nside **2): 
    try:
        counts[i] = len(M.yvals[i])
    except KeyError:
        pass
    
plt.figure(figsize=(10,7))
plt.imshow(counts.reshape(nside,nside), origin='lower')
plt.title('Number per SOM cell')
plt.colorbar();

# %% [markdown]
# #### Every 50 galaxies in cosmodc2 table

# %%
som_pz = som.SelfOrganizingMap(som.Grid(-nside,-nside))
som_pz.fit(dat_arr[::50], maxiter=niter, eta=0.5)
som_pz.map_to_som(dat_arr[::50], dc2_redshifts[::50])

# %%
np.min(dc2_redshifts[::50]), np.max(dc2_redshifts[::50])
# Out:
# (0.014928413481736458, 3.0305308235436694)

# %% [markdown]
# Randomizing at each epoch performed better:

# %%
som_pz.plot_counts_per_cell(dat_arr[::50])

# %% [markdown]
# Shuffling once at the top:

# %%
som_pz.plot_counts_per_cell(dat_arr[::50])

# %%
#Calls the SOMZ mode
M = SelfMap(dat_arr[::50],dc2_redshifts[::50],Ntop=nside,iterations=niter,periodic='yes')
#creates a map
M.create_map()
#evaluates it with the Y entered, or another desired column
M.evaluate_map()

# Plot counts per cell
counts = np.zeros(nside ** 2, dtype=int)
for i in range(nside **2): 
    try:
        counts[i] = len(M.yvals[i])
    except KeyError:
        pass
    
plt.figure(figsize=(10,7))
plt.imshow(counts.reshape(nside,nside), origin='lower')
plt.title('Number per SOM cell')
plt.colorbar();

# %% [markdown]
# How big of an affect do nside and niter have?

# %%
nside = 30
niter = 5

# %%
som_pz = som.SelfOrganizingMap(som.Grid(-nside,-nside))
som_pz.fit(dat_arr[::50], maxiter=niter, eta=0.5)
som_pz.map_to_som(dat_arr[::50], dc2_redshifts[::50])

# %% [markdown]
# Shuffling once at the top:

# %%
som_pz.plot_counts_per_cell(dat_arr[::50])

# %%
#Calls the SOMZ mode
M = SelfMap(dat_arr[::50],dc2_redshifts[::50],Ntop=nside,iterations=niter,periodic='yes')
#creates a map
M.create_map()
#evaluates it with the Y entered, or another desired column
M.evaluate_map()

# Plot counts per cell
counts = np.zeros(nside ** 2, dtype=int)
for i in range(nside **2): 
    try:
        counts[i] = len(M.yvals[i])
    except KeyError:
        pass
    
plt.figure(figsize=(10,7))
plt.imshow(counts.reshape(nside,nside), origin='lower')
plt.title('Number per SOM cell')
plt.colorbar();

# %%
nside = 30
niter = 90

# %%
import cProfile

# %%
# Around 3 seconds / iteration
som_pz = som.SelfOrganizingMap(som.Grid(-nside,-nside))
cProfile.run('som_pz.fit(dat_arr[::50], maxiter=niter, eta=0.5)')
som_pz.map_to_som(dat_arr[::50], dc2_redshifts[::50])
# Out:
#          55171510 function calls in 275.191 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.015    0.015  275.186  275.186 <string>:1(<module>)
#         2    0.000    0.000    0.000    0.000 _internal.py:247(__init__)
#         2    0.000    0.000    0.000    0.000 _internal.py:272(get_data)
#         1    0.000    0.000    0.002    0.002 _methods.py:138(_std)
#         2    0.000    0.000    0.000    0.000 _methods.py:48(_count_reduce_items)
#         1    0.000    0.000    0.001    0.001 _methods.py:58(_mean)
#         1    0.001    0.001    0.002    0.002 _methods.py:91(_var)
#   2903760    2.572    0.000   12.536    0.000 fromnumeric.py:1040(argmin)
#   5807520   10.677    0.000   61.074    0.000 fromnumeric.py:1821(sum)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:2478(prod)
#         1    0.000    0.000    0.001    0.001 fromnumeric.py:2817(mean)
#         1    0.000    0.000    0.002    0.002 fromnumeric.py:2923(std)
#   2903760    1.885    0.000    9.964    0.000 fromnumeric.py:49(_wrapfunc)
#   5807521    9.892    0.000   48.243    0.000 fromnumeric.py:64(_wrapreduction)
#         3    0.000    0.000    0.000    0.000 numeric.py:504(asanyarray)
#         4    0.000    0.000    0.000    0.000 som.py:11(size)
#   2903760   33.818    0.000   82.994    0.000 som.py:141(find_bmu)
#         1  163.840  163.840  275.171  275.171 som.py:157(fit)
#   2903761    0.962    0.000    0.973    0.000 som.py:17(separations)
#         5    0.000    0.000    0.000    0.000 som.py:66(shape)
#         1    0.011    0.011    0.011    0.011 som.py:78(_calculate_separations)
#         2    0.000    0.000    0.000    0.000 som.py:92(<listcomp>)
#         1    0.005    0.005  275.191  275.191 {built-in method builtins.exec}
#   2903761    0.988    0.000    0.988    0.000 {built-in method builtins.getattr}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#   5807526    2.154    0.000    2.154    0.000 {built-in method builtins.isinstance}
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#   5807521    0.776    0.000    0.776    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#         3    0.000    0.000    0.000    0.000 {built-in method numpy.core.multiarray.arange}
#         3    0.000    0.000    0.000    0.000 {built-in method numpy.core.multiarray.array}
#         3    0.000    0.000    0.000    0.000 {built-in method numpy.core.multiarray.empty}
#         1    0.000    0.000    0.000    0.000 {built-in method numpy.core.multiarray.zeros}
#   2903760    7.092    0.000    7.092    0.000 {method 'argmin' of 'numpy.ndarray' objects}
#         1    0.001    0.001    0.001    0.001 {method 'choice' of 'mtrand.RandomState' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#   5807521    0.837    0.000    0.837    0.000 {method 'items' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'normal' of 'mtrand.RandomState' objects}
#   5807524   37.515    0.000   37.515    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#   2903766    2.150    0.000    2.150    0.000 {method 'reshape' of 'numpy.ndarray' objects}

# %% [markdown]
# Randomizing at each epoch:

# %%
som_pz.plot_counts_per_cell(dat_arr[::50])

# %% [markdown]
# Shuffling once at the top:

# %%
som_pz.plot_counts_per_cell(dat_arr[::50])

# %%
#Calls the SOMZ mode
M = SelfMap(dat_arr[::50],dc2_redshifts[::50],Ntop=nside,iterations=niter,periodic='yes')
#creates a map
M.create_map()
#evaluates it with the Y entered, or another desired column
M.evaluate_map()

# Plot counts per cell
counts = np.zeros(nside ** 2, dtype=int)
for i in range(nside **2): 
    try:
        counts[i] = len(M.yvals[i])
    except KeyError:
        pass
    
plt.figure(figsize=(10,7))
plt.imshow(counts.reshape(nside,nside), origin='lower')
plt.title('Number per SOM cell')
plt.colorbar();

# %% [markdown]
# #### Randomly select from first 32264 galaxies
#
# (using different seed than one used to randomize per epoch - when using same seed it doesn't map as uniformly to the SOM, and 'undoes' the effects of initial randomization)

# %%
rng = np.random.RandomState(11)
mix = rng.choice(np.arange(two_pc), size=two_pc, replace=False)

# %%
som_pz = som.SelfOrganizingMap(som.Grid(-nside,-nside))
som_pz.fit(dat_arr[:two_pc][mix], maxiter=niter, eta=0.5)
som_pz.map_to_som(dat_arr[:two_pc][mix], dc2_redshifts[:two_pc][mix])

# %% [markdown]
# Randomizing at each epoch did better:

# %%
som_pz.plot_counts_per_cell(dat_arr[:two_pc][mix])

# %% [markdown]
# Shuffling once at the top performed about the same as in SOMz:

# %%
som_pz.plot_counts_per_cell(dat_arr[:two_pc][mix])

# %%
#Calls the SOMZ mode
M = SelfMap(dat_arr[:two_pc][mix],dc2_redshifts[:two_pc][mix],Ntop=nside,iterations=niter,periodic='yes')
#creates a map
M.create_map()
#evaluates it with the Y entered, or another desired column
M.evaluate_map()

# Plot counts per cell
counts = np.zeros(nside ** 2, dtype=int)
for i in range(nside **2): 
    try:
        counts[i] = len(M.yvals[i])
    except KeyError:
        pass
    
plt.figure(figsize=(10,7))
plt.imshow(counts.reshape(nside,nside), origin='lower')
plt.title('Number per SOM cell')
plt.colorbar();

# %% [markdown]
# Testing different learning rates:

# %%
som_pz = som.SelfOrganizingMap(som.Grid(-nside,-nside))
som_pz.fit(X, maxiter=niter, eta=0.1)
som_pz.map_to_som(X,Y)

# %%
## using mean separation
## eta = 0.1
som_pz.plot_counts_per_cell(X)

# %%
## using max separation
som_pz.plot_counts_per_cell(X)

# %%
plt.plot(som_pz._loss, '.');

# %%
som_pz.plot_statistic()

# %%
som_pz.plot_statistic(column=1)

# %%
# Redshift prediction for input X[10]
best = som_pz.find_bmu(X[200])
print('Mean value prediction is: {:.3}'.format(np.mean(som_pz._target_dist[best])))
# True redshift
print('Real value is: {:.3}'.format(Y[200]))
# Out:
# Mean value prediction is: 0.308
# Real value is: 0.292

# %% [markdown]
# Compare the color value for an input with the mean value of that color in it's best-matching cell:

# %%
color = 0
best = som_pz.find_bmu(X)
mean_color = [np.mean(som_pz._feature_dist[best][:,color]) for best in som_pz.find_bmu(X)]
diff = np.abs(Y - np.asarray(mean_color)) / Y
plt.plot(diff)
plt.xlabel('Input vector')
plt.ylabel('|true - mean feature| / true');

# %%
color = 1
best = som_pz.find_bmu(X)
mean_color = [np.mean(som_pz._feature_dist[best][:,color]) for best in som_pz.find_bmu(X)]
diff = np.abs(Y - np.asarray(mean_color)) / Y
plt.plot(diff);

# %%
color = 2
best = som_pz.find_bmu(X)
mean_color = [np.mean(som_pz._feature_dist[best][:,color]) for best in som_pz.find_bmu(X)]
diff = np.abs(Y - np.asarray(mean_color)) / Y
plt.plot(diff);

# %% [markdown]
# Look at true vs predicted redshifts from pz_bayes:

# %%
pred = [np.mean(som_pz._target_dist[best]) for best in som_pz.find_bmu(X)]
plt.figure(figsize=(8,6))
plt.scatter(Y, pred, s=1)
plt.plot([0,3], [0,3], '--m')
plt.title('pz_bayes')
plt.xlabel('True z')
plt.ylabel('Predicted z')
plt.xlim(0,3)
plt.ylim(0,3);

# %% [markdown]
# Compare SOMz predicted with pz_bayes predicted:

# %%
somz_pred = [np.mean(M.get_vals(X[i])) for i in range(len(X))]
pz_pred = [np.mean(som_pz._target_dist[best]) for best in som_pz.find_bmu(X)]
plt.figure(figsize=(8,6))
plt.scatter(pz_pred, somz_pred, s=1)
plt.plot([0,3], [0,3], '--m')
plt.xlabel('pz predicted')
plt.ylabel('somz predicted')
plt.xlim(0.,3)
plt.ylim(0.,3);

# %% [markdown]
# Compare final weights of each method:

# %%
# SOMz
plt.imshow(M.weights.T.reshape(nside, nside, 3), origin='lower');

# %%
# pz_bayes
plt.imshow(som_pz._weights.T.reshape(nside, nside, 3), origin='lower');

# %% [markdown]
# ### Test on more features: u, u-g, g-r, r-i, i-z

# %%
gc_table = Table.read('cosmodc2_colors/dc2_processed_table.fits', format='fits')

# %%
ugriz_colors = np.asarray([gc_table['mag_u_lsst'], gc_table['u-g_true'], gc_table['g-r_true'], gc_table['r-i_true'], gc_table['i-z_true']]).T
dc2_ugriz = Table(ugriz_colors, names=['u', 'u-g', 'g-r', 'r-i', 'i-z'])

# %%
# Convert to numpy array
colnames = dc2_ugriz.colnames
N, D = len(dc2_ugriz), len(colnames)
dat_arr = np.empty((N,D))

for i, name in enumerate(colnames):
    dat_arr[:,i] = dc2_ugriz[name]

# %%
X = dat_arr[::50]
Y = dc2_redshifts[::50]

# %%
som_pz = som.SelfOrganizingMap(som.Grid(-nside,-nside))
som_pz.fit(X, maxiter=niter)
som_pz.map_to_som(X,Y)

# %%
som_pz.plot_counts_per_cell(X)

# %%
#Calls the SOMZ mode
M = SelfMap(X,Y,Ntop=nside,iterations=niter,periodic='yes')
#creates a map
M.create_map()
#evaluates it with the Y entered, or anyoher desired colum
M.evaluate_map()
#plots the map
M.plot_map()

# %%
# Plot counts per cell
counts = np.zeros(nside ** 2, dtype=int)
for i in range(nside **2): 
    try:
        counts[i] = len(M.yvals[i])
    except KeyError:
        pass
    
plt.figure(figsize=(10,7))
plt.imshow(counts.reshape(15,15), origin='lower')
plt.title('Number per SOM cell')
plt.colorbar();

# %% [markdown]
# ### Test on more features: u, u-g, g-r, r-i, i-z, z-y

# %%
ugrizy_colors = np.asarray([gc_table['mag_u_lsst'], gc_table['u-g_true'], gc_table['g-r_true'], gc_table['r-i_true'], gc_table['i-z_true'], 
                          gc_table['z-y_true']]).T
dc2_ugrizy = Table(ugrizy_colors, names=['u', 'u-g', 'g-r', 'r-i', 'i-z', 'z-y'])

# %%
# Convert to numpy array
colnames = dc2_ugrizy.colnames
N, D = len(dc2_ugrizy), len(colnames)
dat_arr = np.empty((N,D))

for i, name in enumerate(colnames):
    dat_arr[:,i] = dc2_ugrizy[name]

# %%
X = dat_arr[::50]
Y = dc2_redshifts[::50]

# %%
som_pz = som.SelfOrganizingMap(som.Grid(-nside,-nside))
som_pz.fit(X, maxiter=niter)
som_pz.map_to_som(X,Y)

# %%
som_pz.plot_counts_per_cell(X)

# %%
#Calls the SOMZ mode
M = SelfMap(X,Y,Ntop=nside,iterations=niter,periodic='yes')
#creates a map
M.create_map()
#evaluates it with the Y entered, or anyoher desired colum
M.evaluate_map()
#plots the map
M.plot_map()

# %%
# Plot counts per cell
counts = np.zeros(nside ** 2, dtype=int)
for i in range(nside **2): 
    try:
        counts[i] = len(M.yvals[i])
    except KeyError:
        pass
    
plt.figure(figsize=(10,7))
plt.imshow(counts.reshape(15,15), origin='lower')
plt.title('Number per SOM cell')
plt.colorbar();

# %%
plt.imshow(M.weights[:3].T.reshape(15,15,3));

# %%
plt.imshow(som_pz._weights[:3].T.reshape(15,15,3));

# %% [markdown]
# ### Going through each part of the module

# %%
N = 100
nDim = 3
nside = 28
nIter = 30
X = np.random.uniform(size=(N,nDim))
Y = np.random.uniform(size=N)

# %% [markdown]
# `SOMz`

# %%
somz = SelfMap(X,Y, topology='grid', som_type='online', Ntop=nside, iterations=nIter, 
               periodic='yes', dict_dim='', astart=0.8, aend=0.5, importance=None)

# %% [markdown]
# `pz_bayes`

# %%
grid = som.Grid(-nside, -nside)

# %% [markdown]
# Compare grid spacing for both codes:

# %%
fig, axs = plt.subplots(1,2, figsize=(12,5))
axs = axs.ravel()

im0 = axs[0].imshow(grid.separations, origin='lower')
axs[0].set_title('pz_bayes')
fig.colorbar(im0, ax=axs[0])

im1 = axs[1].imshow(somz.distLib, origin='lower')
axs[1].set_title('SOMz')
fig.colorbar(im1, ax=axs[1]);

# %% [markdown]
# #### `create_map()`: initialize map weights

# %% [markdown]
# Randomly initialize weights:

# %%
weights = np.random.rand(nDim, somz.npix) + X[0][0]

# %%
# Initial weight values
plt.imshow(weights.T.reshape(nside, nside, nDim), origin='lower');
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
np.min(weights), np.max(weights)
# Out:
# (0.5623600412108546, 1.5622038208040414)

# %% [markdown]
# pz_bayes weights

# %%
sigs = np.std(X, axis=0)
weights_pz =  sigs.reshape(-1, 1) * np.random.normal(size=(nDim, grid.size))

# %%
# Initial weight values
plt.imshow(weights_pz.T.reshape(nside, nside, nDim), origin='lower');
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
np.min(weights_pz), np.max(weights_pz)
# Out:
# (-0.9555615344782046, 1.0283053730294582)

# %% [markdown]
# Look at the learning rate and sigma widths.
#
# #### SOMz
#
# (see Matias' paper on how learing rate and sigma are defined: https://arxiv.org/pdf/1312.5753.pdf)

# %%
NT = nIter * N
# Initial width of neighborhood
sigma0 = np.max(somz.distLib)
# Smallest non-zero map distance separation
sigma_single = np.min(somz.distLib[np.where(somz.distLib > 0.)])

# %%
tt = 0
somz_alphas = np.empty(nIter)
somz_sigmas = np.empty(nIter)
for it in range(nIter):
    alpha = get_alpha(tt, somz.aps, somz.ape, NT)
    sigma = get_sigma(tt, sigma0, sigma_single, NT)
    # tt increases by N after each epoch
    somz_alphas[it] = alpha
    somz_sigmas[it] = sigma
    for i in range(N):
        tt += 1

# %% [markdown]
# #### pz_bayes

# %%
eta = 0.5
scale = np.max(grid.separations)
pz_alphas = np.empty(nIter)
pz_sigmas = np.empty(nIter)
for it in range(nIter):
    learn_rate = eta ** (it / nIter)
    gauss_width = scale ** (1 - it / nIter)
    pz_alphas[it] = learn_rate
    pz_sigmas[it] = gauss_width

# %% [markdown]
# Compare evolution of learning rate and neighborhood function for each code:

# %%
fig, axs = plt.subplots(1,2, figsize=(12,5))
axs = axs.ravel()

im0 = axs[0].plot(pz_alphas, label='learning rate')
axs[0].set_xlabel('Iteration')
axs[0].set_title('pz_bayes')
axs[0].legend()

im1 = axs[1].plot(somz_alphas, label='learning rate')
axs[1].set_xlabel('Iteration')
axs[1].set_title('SOMz')
axs[1].legend();

# %%
fig, axs = plt.subplots(1,2, figsize=(12,5))
axs = axs.ravel()

im0 = axs[0].plot(pz_sigmas, label='sigma')
axs[0].set_xlabel('Iteration')
axs[0].set_title('pz_bayes')
axs[0].legend()

im1 = axs[1].plot(somz_sigmas, label='sigma')
axs[1].set_xlabel('Iteration')
axs[1].set_title('SOMz')
axs[1].legend();

# %%
np.min(somz.distLib), np.max(somz.distLib), np.min(grid.separations), np.max(grid.separations)
# Out:
# (0.0, 0.7332959212304937, 0.0, 19.79898987322333)

# %%
sigma0, scale
# Out:
# (0.7332959212304937, 19.79898987322333)

# %%
(0.035 - 0.005) / 0.733, (20 - 2.5) / 19.8
# Out:
# (0.040927694406548434, 0.8838383838383838)

# %% [markdown]
# #### Look at how weights change in time
#
# `SOMz`

# %%
def som_best_cell(inputs, return_vals=1):
        """
        Return the closest cell to the input object
        It can return more than one value if needed
        """
        activations = numpy.sum(somz.importance.reshape(-1,1) *
            (np.tile(inputs, (somz.npix, 1)).T - weights) ** 2, axis=0)
        if return_vals == 1:
            best = np.argmin(activations)
            return best, activations
        else:
            best_few = numpy.argsort(activations)
            return best_few[0:return_vals], activations

# %%
best, activation = som_best_cell(X[99])

# %%
def highlight_cell(x,y, ax=None, **kwargs):
    rect = plt.Rectangle((x-.5, y-.5), 1,1, fill=False, **kwargs)
    ax = ax or plt.gca()
    ax.add_patch(rect)
    return rect

# %%
plt.imshow(h(best, somz.distLib, sigma0).reshape(nside, nside), origin='lower')
x = best % nside
y = best // nside
highlight_cell(x,y, color="m", linewidth=3)
plt.colorbar();
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
plt.imshow(somz.distLib[best].reshape(nside, nside), origin='lower')
plt.colorbar();
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
plt.imshow(np.exp(-(somz.distLib[best] ** 2) / sigma0 ** 2).reshape(nside, nside), 
           origin='lower')
plt.colorbar();
# Out:
# <img src="data:image/png;base64,..." width="432">

# %% [markdown]
# Look at the evolution of the neighborhood function as each input vector is introduced to the map during interation = 1:

# %%
# %matplotlib notebook
import matplotlib.animation as animation

fig = plt.figure(figsize=(7,4))
container = []
index_random = random.sample(range(N), N)
for i in range(N):
    best, activation = som_best_cell(X[index_random[i]])
    im = plt.imshow(h(best, somz.distLib, sigma0).reshape(nside, nside), origin='lower')
    x = best % nside
    y = best // nside
    hc = highlight_cell(x,y, color="m", linewidth=3)
    
    container.append([im, hc])
    
    an = animation.ArtistAnimation(fig, container, interval=1000, blit=True,
                                repeat_delay=2000)
# Out:
# <img src="data:image/png;base64,..." width="504">

# %% [markdown]
# Now look at evolution of neighborhood function for all iterations (and every 20 input vectors):

# %%
# %matplotlib notebook
import matplotlib.animation as animation

fig = plt.figure(figsize=(7,4))
container = []
index_random = random.sample(range(N), N)
for it in range(nIter):
    for i in np.arange(start=0, stop=N, step=20):
        best, activation = som_best_cell(X[index_random[i]])
        im = plt.imshow(h(best, somz.distLib, somz_sigmas[it]).reshape(nside, nside), origin='lower')
        x = best % nside
        y = best // nside
        hc = highlight_cell(x,y, color="m", linewidth=3)

        container.append([im, hc])

        an = animation.ArtistAnimation(fig, container, interval=1000, blit=True,
                                    repeat_delay=2000)
# Out:
# <img src="data:image/png;base64,..." width="504">

# %% [markdown]
# `pz_bayes`

# %%
def h_pz(best, sigma):
    return(np.exp(-0.5 * (grid.separations[best] / sigma) ** 2))

def som_best_cell_pz(inputs):
    dx = inputs.reshape(-1, 1) - weights_pz
    distsq = np.sum(dx ** 2, axis=0)
    return(np.argmin(distsq))

# %% [markdown]
# Evolution of neighborhood for iteration = 1:

# %%
# %matplotlib notebook
import matplotlib.animation as animation

fig = plt.figure(figsize=(7,4))
container = []
index_random = random.sample(range(N), N)
for i in range(N):
    best = som_best_cell_pz(X[index_random[i]])
    im = plt.imshow(h_pz(best, sigma0).reshape(nside, nside), origin='lower')
    x = best % nside
    y = best // nside
    hc = highlight_cell(x,y, color="m", linewidth=3)
    
    container.append([im, hc])
    
    an = animation.ArtistAnimation(fig, container, interval=1000, blit=True,
                                repeat_delay=2000)
# Out:
# <img src="data:image/png;base64,..." width="504">

# %% [markdown]
# Now look at evolution of neighborhood function for all iterations (and every 20 input vectors):

# %%
# %matplotlib notebook
import matplotlib.animation as animation

fig = plt.figure(figsize=(7,4))
container = []
index_random = random.sample(range(N), N)
for it in range(nIter):
    for i in np.arange(start=0, stop=N, step=20):
        best = som_best_cell_pz(X[index_random[i]])
        im = plt.imshow(h_pz(best, pz_sigmas[it]).reshape(nside, nside), origin='lower')
        x = best % nside
        y = best // nside
        hc = highlight_cell(x,y, color="m", linewidth=3)

        container.append([im, hc])

        an = animation.ArtistAnimation(fig, container, interval=1000, blit=True,
                                    repeat_delay=2000)
# Out:
# <img src="data:image/png;base64,..." width="504">

# %% [markdown]
# Now let's look at how the weights are updated over time.
#
# `SOMz`

# %%
# %matplotlib notebook
import matplotlib.animation as animation

fig = plt.figure(figsize=(7,4))
container = []
weights = np.random.rand(nDim, somz.npix) + X[0][0]
for it in range(somz.nIter):
    index_random = random.sample(range(somz.np), somz.np)
    for i in np.arange(0,100,20):
        inputs = X[index_random[i]]
        best, activation = som_best_cell(inputs)
        weights += somz_alphas[it] * h(best, somz.distLib, somz_sigmas[it]) * np.transpose(
            (inputs - np.transpose(weights)))

        im = plt.imshow(weights.T.reshape(nside, nside, nDim), origin='lower')
        x = best % nside
        y = best // nside
        hc = highlight_cell(x,y, color="k", linewidth=3)

        container.append([im, hc])

        an = animation.ArtistAnimation(fig, container, interval=1000, blit=True,
                                    repeat_delay=2000)
# Out:
# <img src="data:image/png;base64,..." width="504">

# %% [markdown]
# `pz_bayes`

# %%
fig = plt.figure(figsize=(7,4))
container = []
index_random = random.sample(range(N), N)
sigs = np.std(X, axis=0)
weights_pz =  sigs.reshape(-1, 1) * np.random.normal(size=(nDim, grid.size))
for it in range(nIter):
    for i in range(N):
        inputs = X[index_random[i]]
        best = som_best_cell_pz(inputs)
        weights_pz += pz_alphas[it] * np.exp(-0.5 * (grid.separations[best] / 
                                                     pz_sigmas[it]) ** 2) * (inputs.reshape(-1,1) - weights_pz)
        
plt.imshow(weights_pz.T.reshape(nside, nside, nDim), origin='lower')
# Out:
# <img src="data:image/png;base64,..." width="504">

# %%
# %matplotlib notebook
import matplotlib.animation as animation

fig = plt.figure(figsize=(7,4))
container = []
sigs = np.std(X, axis=0)
weights_pz =  sigs.reshape(-1, 1) * np.random.normal(size=(nDim, grid.size))
for it in range(nIter):
    index_random = random.sample(range(somz.np), somz.np)
    for i in range(N):
        inputs = X[index_random[i]]
        best = som_best_cell_pz(inputs)
        weights_pz += pz_alphas[it] * np.exp(-0.5 * (grid.separations[best] / 
                                                     pz_sigmas[it]) ** 2) * (inputs.reshape(-1,1) - weights_pz)
        
        if N % 20 == 0:
            im = plt.imshow(weights_pz.T.reshape(nside, nside, nDim), origin='lower')
            x = best % nside
            y = best // nside
            hc = highlight_cell(x,y, color="k", linewidth=3)

            container.append([im, hc])

            an = animation.ArtistAnimation(fig, container, interval=1000, blit=True,
                                    repeat_delay=2000)
# Out:
# <img src="data:image/png;base64,..." width="504">

# %%
def som_best_cell_pz_test(inputs, node_weights):
    dx = inputs.reshape(-1, 1) - node_weights
    distsq = np.sum(dx ** 2, axis=0)
    return(np.argmin(distsq))

# %%
def som_best_cell(inputs, return_vals=1):
        """
        Return the closest cell to the input object
        It can return more than one value if needed
        """
        activations = numpy.sum(somz.importance.reshape(-1,1) *
            (np.tile(inputs, (somz.npix, 1)).T - weights) ** 2, axis=0)
        if return_vals == 1:
            best = np.argmin(activations)
            return best, activations
        else:
            best_few = numpy.argsort(activations)
            return best_few[0:return_vals], activations

# %%
for i in range(20):
    if som_best_cell_pz_test(X[i], weights) != som_best_cell(X[i])[0]:
        print('Mismatch')

# %% [markdown]
# BMU's match for both codes. Let's see if anything changes when we use the same initialization of the node weights as in SOMz, and also randomize our input vectors:

# %%
# %matplotlib notebook
import matplotlib.animation as animation

fig = plt.figure(figsize=(7,4))
container = []
#weights_pz = np.random.rand(nDim, nside ** 2) + X[0][0]
sigs = np.std(X, axis=0)
weights_pz =  sigs.reshape(-1, 1) * np.random.normal(size=(nDim, grid.size))
for it in range(nIter):
    #index_random = random.sample(range(N), N)
    for i in range(N):
        #inputs = X[index_random[i]]
        inputs = X[i]
        best = som_best_cell_pz(inputs)
        weights_pz += pz_alphas[it] * np.exp(-0.5 * (grid.separations[best] / 
                                                     pz_sigmas[it]) ** 2) * (inputs.reshape(-1,1) - weights_pz)
        
        if i % 20 == 0:
            im = plt.imshow(weights_pz.T.reshape(nside, nside, nDim), origin='lower')
            x = best % nside
            y = best // nside
            hc = highlight_cell(x,y, color="m", linewidth=3)

            container.append([im, hc])

            an = animation.ArtistAnimation(fig, container, interval=1000, blit=True,
                                        repeat_delay=2000)
# Out:
# <img src="data:image/png;base64,..." width="504">

# %% [markdown]
# Works fine whether we initialize the same and randomize, or not.
#
# Let's look at how each code works on data that's not random:

# %%
path = '/Users/belaabolfathi/Documents/repos/MLZ/mlz/test/'
X = loadtxt(path + 'SDSS_MGS.train', usecols=(1, 2, 3, 4, 5, 6, 7), unpack=True).T
Y = loadtxt(path + 'SDSS_MGS.train', unpack=True, usecols=(0,))
nDim = 7

# %% [markdown]
# SOMz

# %%
somz = SelfMap(X,Y, topology='grid', som_type='online', Ntop=nside, iterations=nIter, 
               periodic='yes', dict_dim='', astart=0.8, aend=0.5, importance=None)

# %%
# %matplotlib notebook
import matplotlib.animation as animation

fig = plt.figure(figsize=(7,4))
container = []
weights = np.random.rand(nDim, somz.npix) + X[0][0]
for it in range(somz.nIter):
    index_random = random.sample(range(somz.np), somz.np)
    for i in np.arange(0,100,20):
        inputs = X[index_random[i]]
        best, activation = som_best_cell(inputs)
        weights += somz_alphas[it] * h(best, somz.distLib, somz_sigmas[it]) * np.transpose(
            (inputs - np.transpose(weights)))

        im = plt.imshow(weights.T.reshape(nside, nside, nDim)[:,:,:3], origin='lower')
        x = best % nside
        y = best // nside
        hc = highlight_cell(x,y, color="k", linewidth=3)

        container.append([im, hc])

        an = animation.ArtistAnimation(fig, container, interval=1000, blit=True,
                                    repeat_delay=2000)
# Out:
# <img src="data:image/png;base64,..." width="504">

# %% [markdown]
# `pz_bayes`

# %%
# %matplotlib notebook
import matplotlib.animation as animation

fig = plt.figure(figsize=(7,4))
container = []
sigs = np.std(X, axis=0)
weights_pz =  sigs.reshape(-1, 1) * np.random.normal(size=(nDim, grid.size))
for it in range(nIter):
    for i in range(N):
        inputs = X[i]
        best = som_best_cell_pz(inputs)
        weights_pz += pz_alphas[it] * np.exp(-0.5 * (grid.separations[best] / 
                                                     pz_sigmas[it]) ** 2) * (inputs.reshape(-1,1) - weights_pz)
        
        if N %  == 0:
            im = plt.imshow(weights_pz.T.reshape(nside, nside, nDim)[:,:,:3], origin='lower')
            x = best % nside
            y = best // nside
            hc = highlight_cell(x,y, color="m", linewidth=3)

            container.append([im, hc])

            an = animation.ArtistAnimation(fig, container, interval=1000, blit=True,
                                        repeat_delay=2000)
# Out:
# <img src="data:image/png;base64,..." width="504">

# %% [markdown]
# Now map input vectors back to the trained SOM.
#
# `SOMz`

# %%
weights = np.random.rand(nDim, somz.npix) + X[0][0]
for it in range(somz.nIter):
    index_random = random.sample(range(somz.np), somz.np)
    for i in range(somz.np):
        inputs = X[index_random[i]]
        best, activation = som_best_cell(inputs)
        weights += somz_alphas[it] * h(best, somz.distLib, somz_sigmas[it]) * np.transpose(
            (inputs - np.transpose(weights)))

# %%
def evaluate_map(inX=X, inY=Y):
        """
        This functions evaluates the map created using the input Y or a new Y (array of labeled attributes)
        It uses the X array passed or new data X as well, the map doesn't change

        :param float inputX: Use this if another set of values for X is wanted using
            the weigths already computed
        :param float inputY: One  dimensional array of the values to be assigned to each cell in the map
            based on the in-memory X passed
        """
        yvals = {}
        ivals = {}
        yvals_arr = np.zeros(somz.npix, dtype=int)
        for i in range(len(inX)):
            inputs = inX[i]
            best, activation = som_best_cell(inputs)
            if not best in yvals: yvals[best] = []
            yvals[best].append(inY[i])
            yvals_arr[best] += 1
            if not best in ivals: ivals[best] = []
            ivals[best].append(i)
        
        return(yvals, ivals, yvals_arr)
    
def plot_map(yvals, min_m=-100, max_m=-100, colbar='yes'):
    """
    Plots the map after evaluating, the cells are colored with the mean value inside each
    one of them
    :param float min_m: Lower limit for coloring the cells, -100 uses min value
    :param float max_m: Upper limit for coloring the cells, -100 uses max value
    :param str colbar: Include a colorbar ('yes','no')
    """

    import matplotlib.pyplot as plt
    import matplotlib.cm as cm
    from matplotlib import collections, transforms
    from matplotlib.colors import colorConverter

    if somz.top == 'grid':
        M = np.zeros(somz.npix) - 20.
        for i in range(somz.npix):
            if i in yvals:
                M[i] = np.mean(yvals[i])
        M2 = np.reshape(M, (somz.Ntop, somz.Ntop))
        plt.figure(figsize=(7,5), dpi=100)
        if min_m == -100: min_m = np.min(M2[np.where(M2 > -10)])
        if max_m == -100: max_m = np.max(M2)
        SM2 = plt.imshow(M2, origin='center', interpolation='nearest', cmap=cm.jet, vmin=min_m, vmax=max_m)
        SM2.cmap.set_under("grey")
        if colbar == 'yes': plt.colorbar()
        plt.axis('off')
    plt.show()

# %%
somz_yvals, somz_ivals, somz_yvals_arr = evaluate_map(X,Y)

# %%
plt.imshow(somz_yvals_arr.reshape(nside, nside), origin='lower')
plt.colorbar();

# %%
plot_map(somz_yvals)

# %%
weights = weights.T
weights_pz = weights_pz.T
weights_norm = (weights - np.min(weights, axis=0) / (np.max(weights, axis=0) - np.min(weights, axis=0)))
weights_pz_norm = (weights_pz - np.min(weights_pz, axis=0) / (np.max(weights_pz, axis=0) - np.min(weights_pz, axis=0)))

# %%
plt.imshow(weights_norm.T.reshape(nside, nside, nDim)[:,:,:3], origin='lower');

# %%
plt.imshow(weights_pz_norm.T.reshape(nside, nside, nDim)[:,:,:3], origin='lower');

# %%
plt.imshow(weights_pz.reshape(nside, nside, nDim)[:,:,:3], origin='lower');

# %% [markdown]
# #### Test  `pz_bayes`

# %%
stemp = som.SelfOrganizingMap(som.Grid(-10,-10))

# %%
stemp.fit(X)

# %%
stemp.plot_counts_per_cell(X)

# %%
stemp.plot_statistic(X,Y)

# %% [markdown]
# #### Compare to SOMz:

# %%
#Calls SOMZ 
M = SelfMap(X,Y,Ntop=10,iterations=100,periodic='yes')
#creates a map
M.create_map()
#evaluates it with the Y entered, or anyoher desired colum
M.evaluate_map()
#plots the map
M.plot_map()

# %%
counts = np.zeros(100, dtype=int)
for i in range(100): 
    try:
        counts[i] = len(M.yvals[i])
    except KeyError:
        pass

# %%
plt.imshow(counts.reshape(10,10), origin='lower')
plt.colorbar();

# %% [markdown]
# ### Now test on cosmoDC2 sample:

# %%
from astropy.table import Table
gc_table = Table.read('cosmodc2_colors/dc2_processed_table.fits', format='fits')

# %%
griz_colors = np.asarray([gc_table['g-r_true'], gc_table['r-i_true'], gc_table['i-z_true']]).T
dc2_griz_colors = Table(griz_colors, names=['g-r', 'r-i', 'i-z'])

# %%
stemp = som.SelfOrganizingMap(som.Grid(-10,-10))

# %%
dat_subset = dc2_griz_colors[::100]

# %%
stemp.fit(dat_subset)

# %%
stemp.plot_counts_per_cell(dat_subset)

# %%
stemp.plot_statistic(dat_subset, gc_table['redshift'][::100])

# %%
idxtemp = stemp.map_to_som(dat_subset)

# %%
plt.hist(idxtemp, bins=50);

# %%
counts = np.zeros(100, dtype=int)
for i in range(100): 
    counts[i] = np.count_nonzero(idxtemp == i)

# %%
plt.imshow(counts.reshape(10,10), origin='lower')
plt.colorbar();

# %%
counts
# Out:
# array([   6,    2,    1,    6,    6,    7,   14,    0,   11,    5,    2,
#           6,    8,   23,   17,   20,    9,   14,   14,    4,    1,    0,
#           2,  160,   18,   31,   83,  188,    1,    3,    5,    4,    4,
#         947,  242,  144,   60,   14,    4,    4,    9,    1,   18,  223,
#          81,   91,    9,    5,    1,    3,    4,    4,    5, 8397, 1168,
#         574,   85,   13,    3,    8,    0,    1,    3,   21,  796, 2380,
#           5,    0,    3,    2,    2,    6,    6,    5,    3,    2,   10,
#           3,    2,    2,    3,    3,    8,    3,    6,    8,    6,    3,
#           0,    2,    1,    4,    1,    5,   12,   11,    1,    3,    4,
#           4])

# %% [markdown]
# Try on SOMz:

# %%
def table_to_array(fits, colnames=None):
    if colnames:
        pass
    else:
        colnames = fits.colnames
    data_arr = np.zeros((len(fits),len(colnames)))
    for k, name in enumerate(colnames):
        data_arr[:,k] = fits[name]
    return(data_arr)

# %%
dat_arr = table_to_array(dat_subset)
z_arr = table_to_array(gc_table[::100], colnames=['redshift'])

# %%
#Calls SOMZ 
M = SelfMap(dat_arr,z_arr,Ntop=10,iterations=100,periodic='yes')
#creates a map
M.create_map()
#evaluates it with the Y entered, or anyoher desired colum
M.evaluate_map()
#plots the map
M.plot_map()

# %%
counts = np.zeros(100, dtype=int)
for i in range(100): 
    try:
        counts[i] = len(M.yvals[i])
    except KeyError:
        pass

# %%
plt.imshow(counts.reshape(10,10), origin='lower')
plt.colorbar();

# %% [markdown]
# Compare weights?

# %%
stemp._weights.shape
# Out:
# (3, 100)

# %%
M.weights.shape
# Out:
# (3, 100)

# %%
plt.imshow(stemp._weights.T.reshape(10,10,3), origin='lower');

# %%
plt.imshow(M.weights.T.reshape(10,10,3), origin='lower');
